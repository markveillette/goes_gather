# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
from aws_utils import GoesAwsBucket, goes_proj, quick_plot

# %%
aws = GoesAwsBucket()
df = aws.list_df(day=123,hour=3,fileprefix='OR_ABI-L2-CMIPC-M6C09')

# %%
data['array']
# Out:
# masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=255,
#   dtype=uint8)

# %%
time='2020-10-17T06:00:00'
data = aws.get('ABI-L2-CMIPF',time,channel=13)
quick_plot(data)
data = aws.get('ABI-L2-ACTPF',time)
im=quick_plot(data)
plt.colorbar(im)
data = aws.get('ABI-L2-ACMF',time)
im=quick_plot(data)
plt.colorbar(im)
# Out:
# ...
# <img src="data:image/png;base64,..." width="432">
# ...
# <img src="data:image/png;base64,..." width="432">
# ...
# <img src="data:image/png;base64,..." width="432">

# %%
data['array'].shape
# Out:
# (1500, 2500)

# %%
if data:
    im=quick_plot(data)

# %%
data = aws.read(df.iloc[0])
data
# Out:
# ...
# {'key': 'CMI',
#  'array': masked_array(
#    data=[[--, --, --, ..., 255.49632263183594, 254.97247314453125,
#           254.43553161621094],
#          [--, --, --, ..., 256.26898193359375, 256.0201721191406,
#           255.49632263183594],
#          [--, --, --, ..., 256.76666259765625, 257.00238037109375,
#           256.76666259765625],
#          ...,
#          [296.3302001953125, 296.2909240722656, 295.75396728515625, ...,
#           297.69219970703125, 297.69219970703125, 297.78387451171875],
#          [296.1861572265625, 296.094482421875, 295.8063659667969, ...,
#           297.73150634765625, 297.69219970703125, 297.63983154296875],
#          [296.57904052734375, 296.2909240722656, 296.52667236328125, ...,
#           297.69219970703125, 297.69219970703125, 297.63983154296875]],
#    mask=[[ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
#          [ True,  True,  True, ..., False, False, False],
# ...

# %%
df = aws.list_df(day=123,hour=3,channel=7)

# %%
d=pd.DataFrame()
d.empty
# Out:
# True

# %%
import datetime
np.argmin(np.abs(df.end_time - datetime.datetime.now()))
# Out:
# 11

# %%
proj = goes_proj(data)

# %%
data = aws.get('ABI-L2-CMIPF',time,channel=13)

# %%
val=np.array([data['array'].mask[i,i] for i in range( data['array'].data.shape[0])],dtype=int)

# %%
np.where(np.abs(val[1:]-val[:-1])==1)
# Out:
# (array([ 795, 4627]),)

# %%
(4627-795) / 256
# Out:
# 14.96875

# %%
len(list(itertools.product(i,i)))
# Out:
# 225

# %%
import itertools
i=range(800,4600,256)
for x0,y0 in itertools.product(i,i):
    print(x0,y0)
# Out:
# 800 800
# 800 1056
# 800 1312
# 800 1568
# 800 1824
# 800 2080
# 800 2336
# 800 2592
# 800 2848
# 800 3104
# 800 3360
# 800 3616
# 800 3872
# 800 4128
# 800 4384
# 1056 800
# 1056 1056
# 1056 1312
# 1056 1568
# 1056 1824
# 1056 2080
# 1056 2336
# 1056 2592
# 1056 2848
# 1056 3104
# 1056 3360
# 1056 3616
# 1056 3872
# 1056 4128
# 1056 4384
# 1312 800
# 1312 1056
# 1312 1312
# 1312 1568
# 1312 1824
# 1312 2080
# 1312 2336
# 1312 2592
# 1312 2848
# 1312 3104
# 1312 3360
# 1312 3616
# 1312 3872
# 1312 4128
# 1312 4384
# 1568 800
# 1568 1056
# 1568 1312
# 1568 1568
# 1568 1824
# 1568 2080
# 1568 2336
# 1568 2592
# 1568 2848
# 1568 3104
# 1568 3360
# 1568 3616
# 1568 3872
# 1568 4128
# 1568 4384
# 1824 800
# 1824 1056
# 1824 1312
# 1824 1568
# 1824 1824
# 1824 2080
# 1824 2336
# 1824 2592
# 1824 2848
# 1824 3104
# 1824 3360
# 1824 3616
# 1824 3872
# 1824 4128
# 1824 4384
# 2080 800
# 2080 1056
# 2080 1312
# 2080 1568
# 2080 1824
# 2080 2080
# 2080 2336
# 2080 2592
# 2080 2848
# 2080 3104
# ...

# %%
list(zip(list(range(800,4627,256)),list(range(800,4627,256))))
# Out:
# [(800, 800),
#  (1056, 1056),
#  (1312, 1312),
#  (1568, 1568),
#  (1824, 1824),
#  (2080, 2080),
#  (2336, 2336),
#  (2592, 2592),
#  (2848, 2848),
#  (3104, 3104),
#  (3360, 3360),
#  (3616, 3616),
#  (3872, 3872),
#  (4128, 4128),
#  (4384, 4384)]

# %%
# %matplotlib notebook
quick_plot(data)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
from netCDF4 import Dataset
nc = Dataset('/tmp/test.nc', 'r')
# Out:
# /Users/markv/miniconda3/envs/aws/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
#v=nc.variables['goes_imager_projection']
np.flipud(nc.variables['y_image_bounds'][:])
# Out:
# masked_array(data=[0.04424, 0.12824],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
import pyproj
p=pyproj.Proj(proj='laea')

# %%
p(13,13,inverse=True)
# Out:
# (0.00011678098693574071, 0.00011756803188505269)

# %%
import pandas as pd
df = pd.Series({'a':1,'b':2})
df.update(pd.Series({'b':3}))
df
# Out:
# a    1
# b    3
# dtype: int64

# %%
df.iloc[0].to_dict()
# Out:
# {'product': 'ABI-L2-CMIPC',
#  'year': '2020',
#  'jd': '123',
#  'hour': '03',
#  'filename': 'OR_ABI-L2-CMIPC-M6C07_G16_s20201230301116_e20201230303501_c20201230303588.nc',
#  'start_time': Timestamp('2020-05-02 03:01:11.600000'),
#  'end_time': Timestamp('2020-05-02 03:03:50.100000'),
#  'creation_time': Timestamp('2020-05-02 03:03:58.800000')}

# %%
import h5py
hf = h5py.File('goes_16_c09_c07_c13_c09_ACTP_ACM.h5','r')
hf.keys()
# Out:
# <KeysViewHDF5 ['ACM', 'ACTP', 'C07', 'C09', 'C13', 'C16']>

# %%
acm=hf['ACM'][:]
c07=hf['C07'][:]
actp=hf['ACTP'][:]
c09=hf['C09'][:]
c13=hf['C13'][:]
c16=hf['C16'][:]

# %%
# %matplotlib inline
idx = 124
fig,axs=plt.subplots(1,6,figsize=(15,5))
axs[0].imshow(acm[idx,:,:],interpolation='nearest')
axs[1].imshow(actp[idx,:,:],interpolation='nearest')
axs[2].imshow(c07[idx,:,:])
axs[3].imshow(c09[idx,:,:])
axs[4].imshow(c13[idx,:,:])
axs[5].imshow(c16[idx,:,:])
